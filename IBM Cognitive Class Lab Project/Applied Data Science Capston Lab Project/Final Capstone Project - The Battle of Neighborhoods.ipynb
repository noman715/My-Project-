# %% [markdown]
# # Capstone Project - The Battle of Neighborhoods

# %% [markdown]
# #### **Import All Libraray**

# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

#!conda install -c conda-forge geopy --yes
from geopy.geocoders import Nominatim
import urllib.request
import json
from bs4 import BeautifulSoup
from urllib.request import urlopen
import requests
from pandas.io.json import json_normalize

import matplotlib.cm as cm
import matplotlib.colors as colors
# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.pyplot as plt
import matplotlib.colors as colors
# %matplotlib inline
from sklearn.cluster import KMeans
#!conda install -c conda-forge folium=0.5.0 --yes
import folium

print('Libraries imported.')
# Out:
# Libraries imported.

# %% [markdown]
#  #### **Foursquare Credentials**

# %%
ClIENT_ID = 'FRU21HS4OFPCCNAPBQXKXAAQ4DBFQJI3141S1IL5WQTRUZA5' # your Foursquare ID
ClIENT_SECRET = 'DTNGYGFCZ30CG1WLO5WZ1GJA4MP4PUWUR12GD4LSQUIGODWF' # your Foursquare Secret
VERSION = '20180604'
LIMIT =30
print('Your credentails:')
print('Foursquare_ID: ' + ClIENT_ID)
print('Foursquare_Secret:' + ClIENT_SECRET)
# Out:
# Your credentails:
# Foursquare_ID: FRU21HS4OFPCCNAPBQXKXAAQ4DBFQJI3141S1IL5WQTRUZA5
# Foursquare_Secret:DTNGYGFCZ30CG1WLO5WZ1GJA4MP4PUWUR12GD4LSQUIGODWF

# %% [markdown]
# #### **Getting its latitude & longitude**

# %%
city = 'Toronto'
geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(city)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 43.653963 -79.387207

# %% [markdown]
# #### **Searching for Hotels**

# %%
search_query = 'Hotel'
radius = 500

url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'\
.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
results = requests.get(url).json()
venues = results['response']['venues']
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...    False
# 1  [{'id': '4bf58dd8d48988d1e7931735', 'name': 'J...    False
# 2  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...    False
# 3  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...    False
# 4  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...    False
#
#                          id       location.address location.cc location.city  \
# 0  4ab2d511f964a5209b6c20e3  123 Queen Street West          CA       Toronto
# 1  4b68aed1f964a520de862be3         194 Queen St W          CA       Toronto
# 2  58b7d72dcc05d161570bd712  123 Queen Street West          CA       Toronto
# 3  52ce14b0498e50457ce11780    108 Chestnut Street          CA       Toronto
# 4  4f343a31e4b0230a3b337a90         123 Test Drive          CA       Toronto
#
#   location.country location.crossStreet  location.distance  \
# 0           Canada          at York St.                416
# 1           Canada  Queen & St. Patrick                400
# 2           Canada                  NaN                410
# 3           Canada          Dundas St W                124
# 4           Canada      at somewhere St                500
#
#                            location.formattedAddress  \
# 0  [123 Queen Street West (at York St.), Toronto ...
# 1  [194 Queen St W (Queen & St. Patrick), Toronto...
# 2  [123 Queen Street West, Toronto ON M5H 2M9, Ca...
# 3  [108 Chestnut Street (Dundas St W), Toronto ON...
# 4  [123 Test Drive (at somewhere St), Toronto ON ...
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 43.65112928325278...     43.651129
# 1  [{'label': 'display', 'lat': 43.65050475544005...     43.650505
# 2  [{'label': 'display', 'lat': 43.65101646682632...     43.651016
# 3  [{'label': 'display', 'lat': 43.6546083, 'lng'...     43.654608
# 4  [{'label': 'display', 'lat': 43.658434, 'lng':...     43.658434
#
#    location.lng location.neighborhood location.postalCode location.state  \
# 0    -79.383829                   NaN             M5H 2M9             ON
# 1    -79.388577                   NaN             M5V 1Z1             ON
# 2    -79.384148                   NaN             M5H 2M9             ON
# 3    -79.385942                   NaN             M5G 1R3             ON
# 4    -79.387894                   NaN             M2M 2M2             ON
#
#                                           name    referralId venuePage.id
# 0                Sheraton Centre Toronto Hotel  v-1560907858          NaN
# 1               The Rex Hotel Jazz & Blues Bar  v-1560907858     62225795
# 2                Sheraton Centre Toronto Hotel  v-1560907858    402127087
# 3  DoubleTree by Hilton Hotel Toronto Downtown  v-1560907858          NaN
# 4                               VFM Test Hotel  v-1560907858          NaN

# %% [markdown]
# #### **Cleaning the Dataframe**

# %%
clean_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')]+ ['id']
clean_dataframe = dataframe.loc[:,clean_columns]

def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

clean_dataframe['categories'] = clean_dataframe.apply(get_category_type, axis=1)

clean_dataframe.columns = [column.split('.')[-1] for column in clean_dataframe.columns]

clean_dataframe.head()
# Out:
#                                           name categories  \
# 0                Sheraton Centre Toronto Hotel      Hotel
# 1               The Rex Hotel Jazz & Blues Bar  Jazz Club
# 2                Sheraton Centre Toronto Hotel      Hotel
# 3  DoubleTree by Hilton Hotel Toronto Downtown      Hotel
# 4                               VFM Test Hotel      Hotel
#
#                  address  cc     city country          crossStreet  distance  \
# 0  123 Queen Street West  CA  Toronto  Canada          at York St.       416
# 1         194 Queen St W  CA  Toronto  Canada  Queen & St. Patrick       400
# 2  123 Queen Street West  CA  Toronto  Canada                  NaN       410
# 3    108 Chestnut Street  CA  Toronto  Canada          Dundas St W       124
# 4         123 Test Drive  CA  Toronto  Canada      at somewhere St       500
#
#                                     formattedAddress  \
# 0  [123 Queen Street West (at York St.), Toronto ...
# 1  [194 Queen St W (Queen & St. Patrick), Toronto...
# 2  [123 Queen Street West, Toronto ON M5H 2M9, Ca...
# 3  [108 Chestnut Street (Dundas St W), Toronto ON...
# 4  [123 Test Drive (at somewhere St), Toronto ON ...
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lat': 43.65112928325278...  43.651129 -79.383829
# 1  [{'label': 'display', 'lat': 43.65050475544005...  43.650505 -79.388577
# 2  [{'label': 'display', 'lat': 43.65101646682632...  43.651016 -79.384148
# 3  [{'label': 'display', 'lat': 43.6546083, 'lng'...  43.654608 -79.385942
# 4  [{'label': 'display', 'lat': 43.658434, 'lng':...  43.658434 -79.387894
#
#   neighborhood postalCode state                        id
# 0          NaN    M5H 2M9    ON  4ab2d511f964a5209b6c20e3
# 1          NaN    M5V 1Z1    ON  4b68aed1f964a520de862be3
# 2          NaN    M5H 2M9    ON  58b7d72dcc05d161570bd712
# 3          NaN    M5G 1R3    ON  52ce14b0498e50457ce11780
# 4          NaN    M2M 2M2    ON  4f343a31e4b0230a3b337a90

# %%
clean_dataframe2= clean_dataframe.drop(['cc', 'city', 'country', 'crossStreet', 'distance', 'formattedAddress',\
                                        'labeledLatLngs','neighborhood', 'id'], axis=1)
clean_dataframe2
# Out:
#                                               name              categories  \
# 0                    Sheraton Centre Toronto Hotel                   Hotel
# 1                   The Rex Hotel Jazz & Blues Bar               Jazz Club
# 2                    Sheraton Centre Toronto Hotel                   Hotel
# 3      DoubleTree by Hilton Hotel Toronto Downtown                   Hotel
# 4                                   VFM Test Hotel                   Hotel
# 5   Sheraton Centre Toronto Hotel - Grand Ballroom                Ballroom
# 6                                  Stathcona Hotel                   Hotel
# 7    hilton hotel, richmondstreet E, 145,  toronto              Hotel Pool
# 8                                Be SixFifty Hotel                   Hotel
# 9                                        650 Hotel                   Hotel
# 10                                  Hilton Toronto                   Hotel
# 11                           89 Chestnut Residence  College Residence Hall
# 12    Marriott Downtown at CF Toronto Eaton Centre                   Hotel
# 13                   Op mijn hotelkamer In Toronto                   Hotel
# 14                              Shangri-La Toronto                   Hotel
# 15          Lobby Lounge at the Shangri-La Toronto                  Lounge
# 16                                  Fitness Centre                     Gym
# 17                                  Fitness Centre                     Gym
# 18                                            Pool                    Pool
# 19                                   Bistro on Two          Breakfast Spot
# 20                                   Kumar For Men             Men's Store
# 21                                  Grand Ballroom             Event Space
#
#                   address        lat        lng postalCode    state
# 0   123 Queen Street West  43.651129 -79.383829    M5H 2M9       ON
# 1          194 Queen St W  43.650505 -79.388577    M5V 1Z1       ON
# 2   123 Queen Street West  43.651016 -79.384148    M5H 2M9       ON
# 3     108 Chestnut Street  43.654608 -79.385942    M5G 1R3       ON
# 4          123 Test Drive  43.658434 -79.387894    M2M 2M2       ON
# 5   123 Queen Street West  43.651200 -79.384520        NaN       ON
# 6                     NaN  43.654947 -79.386359        NaN       ON
# 7   Richmondstreet E, 145  43.650625 -79.385488        NaN       ON
# 8          650 Bay Street  43.657120 -79.384560        NaN       ON
# 9          650 Bay Street  43.657046 -79.384411        NaN       ON
# 10      145 Richmond St W  43.650143 -79.385488    M5H 2L2       ON
# 11        89 Chestnut St.  43.654160 -79.385291    M5G 1R1       ON
# 12         525 Bay Street  43.654728 -79.382422    M5G 2L2       ON
# 13                    NaN  43.654235 -79.386208        NaN       ON
# 14    188 University Ave.  43.649129 -79.386557    M5H 0A3       ON
# 15    188 University Ave.  43.649155 -79.386546    M5H 0A3       ON
# 16        Sheraton Centre  43.650985 -79.384002    M5H 2M9       ON
# 17            525 Bay St.  43.654690 -79.381739    M5G 2L2       ON
# 18       Intercontinental  43.650975 -79.384053        NaN  Ontario
# 19        123 Queen St. W  43.651011 -79.383658    M5H 2M9       ON
# 20        Sheraton Centre  43.651044 -79.383302    M5H 2M9       ON
# 21        123 Queen St. W  43.651217 -79.383771    M5H 2M9       ON

# %%
clean_dataframe3 = clean_dataframe2.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
clean_dataframe3
# Out:
#                                             name              categories  \
# 0                  Sheraton Centre Toronto Hotel                   Hotel
# 1                 The Rex Hotel Jazz & Blues Bar               Jazz Club
# 2                  Sheraton Centre Toronto Hotel                   Hotel
# 3    DoubleTree by Hilton Hotel Toronto Downtown                   Hotel
# 4                                 VFM Test Hotel                   Hotel
# 10                                Hilton Toronto                   Hotel
# 11                         89 Chestnut Residence  College Residence Hall
# 12  Marriott Downtown at CF Toronto Eaton Centre                   Hotel
# 14                            Shangri-La Toronto                   Hotel
# 15        Lobby Lounge at the Shangri-La Toronto                  Lounge
# 16                                Fitness Centre                     Gym
# 17                                Fitness Centre                     Gym
# 19                                 Bistro on Two          Breakfast Spot
# 20                                 Kumar For Men             Men's Store
# 21                                Grand Ballroom             Event Space
#
#                   address        lat        lng postalCode state
# 0   123 Queen Street West  43.651129 -79.383829    M5H 2M9    ON
# 1          194 Queen St W  43.650505 -79.388577    M5V 1Z1    ON
# 2   123 Queen Street West  43.651016 -79.384148    M5H 2M9    ON
# 3     108 Chestnut Street  43.654608 -79.385942    M5G 1R3    ON
# 4          123 Test Drive  43.658434 -79.387894    M2M 2M2    ON
# 10      145 Richmond St W  43.650143 -79.385488    M5H 2L2    ON
# 11        89 Chestnut St.  43.654160 -79.385291    M5G 1R1    ON
# 12         525 Bay Street  43.654728 -79.382422    M5G 2L2    ON
# 14    188 University Ave.  43.649129 -79.386557    M5H 0A3    ON
# 15    188 University Ave.  43.649155 -79.386546    M5H 0A3    ON
# 16        Sheraton Centre  43.650985 -79.384002    M5H 2M9    ON
# 17            525 Bay St.  43.654690 -79.381739    M5G 2L2    ON
# 19        123 Queen St. W  43.651011 -79.383658    M5H 2M9    ON
# 20        Sheraton Centre  43.651044 -79.383302    M5H 2M9    ON
# 21        123 Queen St. W  43.651217 -79.383771    M5H 2M9    ON

# %%
array= ['Hotel', 'Event Space']
hotel_dataframe= clean_dataframe3.loc[clean_dataframe3['categories'].isin(array)]
hotel_dataframe
# Out:
#                                             name   categories  \
# 0                  Sheraton Centre Toronto Hotel        Hotel
# 2                  Sheraton Centre Toronto Hotel        Hotel
# 3    DoubleTree by Hilton Hotel Toronto Downtown        Hotel
# 4                                 VFM Test Hotel        Hotel
# 10                                Hilton Toronto        Hotel
# 12  Marriott Downtown at CF Toronto Eaton Centre        Hotel
# 14                            Shangri-La Toronto        Hotel
# 21                                Grand Ballroom  Event Space
#
#                   address        lat        lng postalCode state
# 0   123 Queen Street West  43.651129 -79.383829    M5H 2M9    ON
# 2   123 Queen Street West  43.651016 -79.384148    M5H 2M9    ON
# 3     108 Chestnut Street  43.654608 -79.385942    M5G 1R3    ON
# 4          123 Test Drive  43.658434 -79.387894    M2M 2M2    ON
# 10      145 Richmond St W  43.650143 -79.385488    M5H 2L2    ON
# 12         525 Bay Street  43.654728 -79.382422    M5G 2L2    ON
# 14    188 University Ave.  43.649129 -79.386557    M5H 0A3    ON
# 21        123 Queen St. W  43.651217 -79.383771    M5H 2M9    ON

# %%
df_hotels = hotel_dataframe.drop_duplicates(subset='name', keep="first")
df_hotels
# Out:
#                                             name   categories  \
# 0                  Sheraton Centre Toronto Hotel        Hotel
# 3    DoubleTree by Hilton Hotel Toronto Downtown        Hotel
# 4                                 VFM Test Hotel        Hotel
# 10                                Hilton Toronto        Hotel
# 12  Marriott Downtown at CF Toronto Eaton Centre        Hotel
# 14                            Shangri-La Toronto        Hotel
# 21                                Grand Ballroom  Event Space
#
#                   address        lat        lng postalCode state
# 0   123 Queen Street West  43.651129 -79.383829    M5H 2M9    ON
# 3     108 Chestnut Street  43.654608 -79.385942    M5G 1R3    ON
# 4          123 Test Drive  43.658434 -79.387894    M2M 2M2    ON
# 10      145 Richmond St W  43.650143 -79.385488    M5H 2L2    ON
# 12         525 Bay Street  43.654728 -79.382422    M5G 2L2    ON
# 14    188 University Ave.  43.649129 -79.386557    M5H 0A3    ON
# 21        123 Queen St. W  43.651217 -79.383771    M5H 2M9    ON

# %%
df_hotel = df_hotels[df_hotels.postalCode == 'M5H 2M9']
df_hotel
# Out:
#                              name   categories                address  \
# 0   Sheraton Centre Toronto Hotel        Hotel  123 Queen Street West
# 21                 Grand Ballroom  Event Space        123 Queen St. W
#
#           lat        lng postalCode state
# 0   43.651129 -79.383829    M5H 2M9    ON
# 21  43.651217 -79.383771    M5H 2M9    ON

# %% [markdown]
# #### **Searching Parks**

# %%
search_query = 'Park'
radius = 10000

url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'\
.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=FRU21HS4OFPCCNAPBQXKXAAQ4DBFQJI3141S1IL5WQTRUZA5&client_secret=DTNGYGFCZ30CG1WLO5WZ1GJA4MP4PUWUR12GD4LSQUIGODWF&ll=43.653963,-79.387207&v=20180604&query=Park&radius=10000&limit=30'

# %%
presults = requests.get(url).json()
venues = presults['response']['venues']
park_dataframe = json_normalize(venues)
park_dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1fd931735', 'name': 'M...    False
# 1  [{'id': '4bf58dd8d48988d163941735', 'name': 'P...    False
# 2  [{'id': '4bf58dd8d48988d163941735', 'name': 'P...    False
# 3  [{'id': '4d954b06a243a5684965b473', 'name': 'R...    False
# 4  [{'id': '4bf58dd8d48988d175941735', 'name': 'G...    False
#
#                          id    location.address location.cc location.city  \
# 0  4b170e47f964a5208cc123e3  691 University Ave          CA       Toronto
# 1  4b54deadf964a520a3d027e3                 NaN          CA       Toronto
# 2  4ad4c05ef964a520bdf620e3  1053 Dundas St. W.          CA       Toronto
# 3  4ad80fcef964a520a61021e3       280 Simcoe St          CA       Toronto
# 4  59ddd7469ba3e51a75459568    382 Yonge Street          CA       Toronto
#
#   location.country location.crossStreet  location.distance  \
# 0           Canada        at College St                716
# 1           Canada                  NaN                423
# 2           Canada    at Gore Vale Ave.               2271
# 3           Canada   Dundas Street West                282
# 4           Canada                  NaN                695
#
#                            location.formattedAddress  \
# 0  [691 University Ave (at College St), Toronto O...
# 1  [btwn College, University, Queen & Spadina, To...
# 2  [1053 Dundas St. W. (at Gore Vale Ave.), Toron...
# 3  [280 Simcoe St (Dundas Street West), Toronto O...
# 4     [382 Yonge Street, Toronto ON M5G 1S8, Canada]
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 43.66000635700919...     43.660006
# 1  [{'label': 'display', 'lat': 43.65248755299856...     43.652488
# 2  [{'label': 'display', 'lat': 43.64707192840234...     43.647072
# 3  [{'label': 'display', 'lat': 43.65544241747622...     43.655442
# 4  [{'label': 'display', 'lat': 43.6592634, 'lng'...     43.659263
#
#    location.lng location.postalCode location.state  \
# 0    -79.390272             M5G 2P1             ON
# 1    -79.392053                 NaN             ON
# 2    -79.413756             M5H 2N2             ON
# 3    -79.390056             M5T 2Y5             ON
# 4    -79.382632             M5G 1S8             ON
#
#                             name    referralId venuePage.id
# 0    Queen's Park Subway Station  v-1560908117          NaN
# 1                    Grange Park  v-1560908117          NaN
# 2         Trinity Bellwoods Park  v-1560908117          NaN
# 3                  One Park Lane  v-1560908117          NaN
# 4  Crunch Fitness - College Park  v-1560908117    532736199

# %% [markdown]
# #### **Cleaning The Dataframe**

# %%
park_clean_columns = ['name', 'categories'] + [col for col in park_dataframe.columns if col.startswith('location.')]+ ['id']
clean_park_dataframe = park_dataframe.loc[:,park_clean_columns]

def get_category_type(row):
    try:
        categories_list1 = row['categories']
    except:
        categories_list1 = row['venue.categories']
        
    if len(categories_list1) == 0:
        return None
    else:
        return categories_list1[0]['name']

clean_park_dataframe['categories'] = clean_park_dataframe.apply(get_category_type, axis=1)

clean_park_dataframe.columns = [column.split('.')[-1] for column in clean_park_dataframe.columns]

clean_park_dataframe2= clean_park_dataframe.drop(['cc', 'city', 'country', 'crossStreet', 'distance', 'formattedAddress',\
                                        'labeledLatLngs', 'id'], axis=1)
clean_park_dataframe2
clean_park_dataframe3 = clean_park_dataframe2.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
clean_park_dataframe3
df_park = clean_park_dataframe3[clean_park_dataframe3.categories == 'Park']
df_park
# Out:
#                       name categories                       address  \
# 2   Trinity Bellwoods Park       Park            1053 Dundas St. W.
# 6     Bellevue Square Park       Park  btwn Bellevue & Augusta Ave.
# 8             Queen's Park       Park               University Ave.
# 11     Riverdale Park West       Park               500 Gerrard St.
# 13               High Park       Park              1873 Bloor St. W
# 17     Riverdale Park East       Park             550 Broadview Ave
# 20         Coronation Park       Park        711 Lake Shore Blvd. W
# 28      Canoe Landing Park       Park             50 Fort York Blvd
# 29       Barbara Hall Park       Park                 519 Church St
#
#           lat        lng postalCode state
# 2   43.647072 -79.413756    M5H 2N2    ON
# 6   43.653610 -79.402199    M5T 2N4    ON
# 8   43.663946 -79.392180    M5R 2E8    ON
# 11  43.666048 -79.360941    M5A 2H3    ON
# 13  43.646479 -79.463425    M6R 2Z3    ON
# 17  43.669951 -79.355493    M4K 2P1    ON
# 20  43.634553 -79.405403    M5V 3T7    ON
# 28  43.638762 -79.397067    M5V 3Z1    ON
# 29  43.666879 -79.381068    M4Y 2K9    ON

# %% [markdown]
# #### **Searching Restaurant**

# %%
search_query = 'Restaurant'
radius = 10000

# Define the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
Rresults = requests.get(url).json()

venues = Rresults['response']['venues']

Restaurant_dataframe = json_normalize(venues)
Restaurant_dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d14e941735', 'name': 'A...    False
# 1  [{'id': '4bf58dd8d48988d1f5931735', 'name': 'D...    False
# 2  [{'id': '4bf58dd8d48988d1c4941735', 'name': 'R...    False
# 3  [{'id': '4bf58dd8d48988d123941735', 'name': 'W...    False
# 4  [{'id': '4bf58dd8d48988d1d1941735', 'name': 'N...    False
#
#                          id     location.address location.cc location.city  \
# 0  4ad4c05ff964a52048f720e3  110 Chestnut Street          CA       Toronto
# 1  4ad4c060f964a5207ff720e3     323 Spadina Ave.          CA       Toronto
# 2  4b223f5af964a520ba4424e3        225 Frnt St W          CA       Toronto
# 3  4ad4c05cf964a520dff520e3       301 Front St W          CA       Toronto
# 4  4b266f05f964a520657b24e3      266 Spadina Ave          CA       Toronto
#
#   location.country location.crossStreet  location.distance  \
# 0           Canada                  NaN                145
# 1           Canada        at D'Arcy St.                922
# 2           Canada                  NaN               1039
# 3           Canada      301 Front St. W               1271
# 4           Canada       at Willison Sq                892
#
#                            location.formattedAddress  \
# 0  [110 Chestnut Street, Toronto ON M5G 1R3, Canada]
# 1  [323 Spadina Ave. (at D'Arcy St.), Toronto ON ...
# 2        [225 Frnt St W, Toronto ON M5V 2X3, Canada]
# 3  [301 Front St W (301 Front St. W), Toronto ON ...
# 4  [266 Spadina Ave (at Willison Sq), Toronto ON ...
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 43.65488413420439...     43.654884
# 1  [{'label': 'display', 'lat': 43.65431754076345...     43.654318
# 2  [{'label': 'display', 'lat': 43.64474919591934...     43.644749
# 3  [{'label': 'display', 'lat': 43.64253731714456...     43.642537
# 4  [{'label': 'display', 'lat': 43.6522783893466,...     43.652278
#
#    location.lng   location.neighborhood location.postalCode location.state  \
# 0    -79.385931                     NaN             M5G 1R3             ON
# 1    -79.398650       Kensington Market             M5T 2E9             ON
# 2    -79.385113  Entertainment District             M5V 2X3             ON
# 3    -79.387042                     NaN             M5V 2T6             ON
# 4    -79.398039                     NaN             M5T 2E4             ON
#
#                               name    referralId venuePage.id
# 0  Hemispheres Restaurant & Bistro  v-1560908328          NaN
# 1           Rol San Restaurant 龍笙棧  v-1560908328          NaN
# 2           Azure Restaurant & Bar  v-1560908328    136175835
# 3                   360 Restaurant  v-1560908328          NaN
# 4   Goldstone Noodle Restaurant 金石  v-1560908328          NaN

# %% [markdown]
# #### **Cleaning Dataframe**

# %%
Restaurant_clean_columns = ['name', 'categories'] + [col for col in Restaurant_dataframe.columns if col.startswith('location.')]+ ['id']
clean_Restaurant_dataframe = Restaurant_dataframe.loc[:,Restaurant_clean_columns]

def get_category_type(row):
    try:
        categories_list3 = row['categories']
    except:
        categories_list3 = row['venue.categories']
        
    if len(categories_list3) == 0:
        return None
    else:
        return categories_list3[0]['name']

clean_Restaurant_dataframe['categories'] = clean_Restaurant_dataframe.apply(get_category_type, axis=1)

clean_Restaurant_dataframe.columns = [column.split('.')[-1] for column in clean_Restaurant_dataframe.columns]

clean_Restaurant_dataframe2= clean_Restaurant_dataframe.drop(['cc', 'city', 'country', 'crossStreet', 'distance', 'formattedAddress',\
                                        'labeledLatLngs', 'neighborhood', 'id'], axis=1)
clean_Restaurant_dataframe2


df_Restaurant = clean_Restaurant_dataframe2.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
df_Restaurant
# Out:
#                                               name               categories  \
# 0                  Hemispheres Restaurant & Bistro      American Restaurant
# 1                           Rol San Restaurant 龍笙棧       Dim Sum Restaurant
# 2                           Azure Restaurant & Bar               Restaurant
# 3                                   360 Restaurant                 Wine Bar
# 4                   Goldstone Noodle Restaurant 金石             Noodle House
# 6                            Victoria's Restaurant               Restaurant
# 7                          Swatow Restaurant 汕頭小食家       Chinese Restaurant
# 8                   The Hot House Restaurant & Bar      American Restaurant
# 9                         New Sky Restaurant 小沙田食家       Chinese Restaurant
# 10                         Victor Restaurant & Bar                      Bar
# 11                   Green Tea Restaurant Downtown       Chinese Restaurant
# 13                        Ka Chi Korean Restaurant        Korean Restaurant
# 14                    Aroma Fine Indian Restaurant        Indian Restaurant
# 15         Tasty's Caribbean Restaurant & Catering     Caribbean Restaurant
# 16  Sassafraz | Cafe | Restaurant | Private Events              Event Space
# 17                   Hong Shing Chinese Restaurant       Chinese Restaurant
# 18                     Woodlot Restaurant & Bakery  New American Restaurant
# 19                  Insomnia Restaurant and Lounge               Restaurant
# 21                            Montecito Restaurant               Restaurant
# 22                         The Lakeview Restaurant                    Diner
# 23                 Bright Pearl Seafood Restaurant       Chinese Restaurant
# 24                      Matisse Restaurant And Bar               Restaurant
# 25                               Tundra Restaurant               Restaurant
# 27               Kensington Cornerstone Restaurant           Breakfast Spot
# 28                               Studio Restaurant           Breakfast Spot
# 29                         Little India Restaurant        Indian Restaurant
#
#                             address        lat        lng postalCode state
# 0               110 Chestnut Street  43.654884 -79.385931    M5G 1R3    ON
# 1                  323 Spadina Ave.  43.654318 -79.398650    M5T 2E9    ON
# 2                     225 Frnt St W  43.644749 -79.385113    M5V 2X3    ON
# 3                    301 Front St W  43.642537 -79.387042    M5V 2T6    ON
# 4                   266 Spadina Ave  43.652278 -79.398039    M5T 2E4    ON
# 6               37 King Street East  43.649298 -79.376431    M5C 1E9    ON
# 7                  309 Spadina Ave.  43.653866 -79.398334    M5T 2E6    ON
# 8                      35 Church St  43.648824 -79.373702    M5E 1T3    ON
# 9                  353 Spadina Ave.  43.655337 -79.398897    M5T 2G3    ON
# 10                 30 Mercer Street  43.645634 -79.391125    M5V 1H3    ON
# 11  261 Spadina Avenue. Upper level  43.652488 -79.397501    M5T 2E3    ON
# 13                  8 St Andrew St.  43.654307 -79.399277    M5T 1K6    ON
# 14                   287 King St. W  43.646463 -79.389644    M5V 1J5    ON
# 15                  405 Spadina Ave  43.656794 -79.399251    M5T 2G6    ON
# 16            100 Cumberland Street  43.670342 -79.391041    M5R 1A6    ON
# 17                  195 Dundas St W  43.654925 -79.387089    M5G 1C7    ON
# 18              293 Palmerston Ave.  43.655765 -79.409929    M6J 2J3    ON
# 19                563 Bloor St West  43.665180 -79.410966    M5S 1Y6    ON
# 21                299 Adelaide St W  43.647644 -79.391069    M5V 1P7    ON
# 22                1132 Dundas St. W  43.649435 -79.420390    M6J 1X2    ON
# 23           346-348 Spadina Avenue  43.654219 -79.399125    M5T 2G2    ON
# 24                     90 Bloor St.  43.670574 -79.384856    M4W 1A7    ON
# 25         145 Richmond Street West  43.650010 -79.385608    M5H 2L2    ON
# 27               2A Kensington Ave.  43.652803 -79.399958    M5T 2J7    ON
# 28                   389 Church St.  43.661500 -79.379319        M5B    ON
# 29                  255 Queen St. W  43.650319 -79.388998    M5V 1Z4    ON

# %% [markdown]
# #### **Searching Cafeteria**

# %%
search_query = 'Cafeteria'
radius = 10000

url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url

cresults = requests.get(url).json()

venues = cresults['response']['venues']

Cafeteria_dataframe = json_normalize(venues)
Cafeteria_dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d16e941735', 'name': 'F...    False
# 1  [{'id': '4bf58dd8d48988d142941735', 'name': 'A...    False
# 2  [{'id': '4bf58dd8d48988d1c1941735', 'name': 'M...    False
# 3  [{'id': '4bf58dd8d48988d1a1941735', 'name': 'C...    False
# 4  [{'id': '4bf58dd8d48988d128941735', 'name': 'C...    False
#
#                          id                           location.address  \
# 0  4f9165bde4b04fef0087e4e2  The Hospital for Sick Children (SickKids)
# 1  528e99a211d262edc3708a6f                            388 Spadina Ave
# 2  56b2c90a498e9f0e73d6bed6                             974 College St
# 3  4ec2b68a8231a83de8c45191                             100 McCaul St.
# 4  53bd6dfe498e6c1d3bc9333e                                        NaN
#
#   location.cc location.city location.country location.crossStreet  \
# 0          CA       Toronto           Canada                  NaN
# 1          CA       Toronto           Canada         at Nassau St
# 2          CA       Toronto           Canada                  NaN
# 3          CA       Toronto           Canada         Second Floor
# 4          CA       Toronto           Canada                  NaN
#
#    location.distance                          location.formattedAddress  \
# 0                372  [The Hospital for Sick Children (SickKids), To...
# 1                977  [388 Spadina Ave (at Nassau St), Toronto ON M5...
# 2               3260       [974 College St, Toronto ON M6H 1A5, Canada]
# 3                389  [100 McCaul St. (Second Floor), Toronto ON, Ca...
# 4                260                               [Toronto ON, Canada]
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 43.65720930549997...     43.657209
# 1  [{'label': 'display', 'lat': 43.65545427446646...     43.655454
# 2  [{'label': 'display', 'lat': 43.65341883567197...     43.653419
# 3  [{'label': 'display', 'lat': 43.65278016892648...     43.652780
# 4  [{'label': 'display', 'lat': 43.655657, 'lng':...     43.655657
#
#    location.lng location.postalCode location.state  \
# 0    -79.386063                 NaN             ON
# 1    -79.399163             M5T 2G5             ON
# 2    -79.427678             M6H 1A5             ON
# 3    -79.391762                 NaN             ON
# 4    -79.389443                 NaN             ON
#
#                             name    referralId
# 0                      Cafeteria  v-1560908479
# 1              Stay Cafeteria 慢走  v-1560908479
# 2                      Cafeteria  v-1560908479
# 3                 OCAD Cafeteria  v-1560908479
# 4  Industrial Alliance Cafeteria  v-1560908479

# %% [markdown]
# #### **Cleaning Dataframe**

# %%
Cafeteria_clean_columns = ['name', 'categories'] + [col for col in Cafeteria_dataframe.columns if col.startswith('location.')]+ ['id']
clean_Cafeteria_dataframe = Cafeteria_dataframe.loc[:,Cafeteria_clean_columns]

def get_category_type(row):
    try:
        categories_list4 = row['categories']
    except:
        categories_list4 = row['venue.categories']
        
    if len(categories_list4) == 0:
        return None
    else:
        return categories_list4[0]['name']

clean_Cafeteria_dataframe['categories'] = clean_Cafeteria_dataframe.apply(get_category_type, axis=1)

clean_Cafeteria_dataframe.columns = [column.split('.')[-1] for column in clean_Cafeteria_dataframe.columns]
clean_Cafeteria_dataframe2= clean_Cafeteria_dataframe.drop(['cc', 'city', 'country', 'crossStreet', 'distance', 'formattedAddress',\
                                        'labeledLatLngs', 'id'], axis=1)
clean_Cafeteria_dataframe2
df_Cafeteria = clean_Cafeteria_dataframe2.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
df_Cafeteria
# Out:
#                                      name          categories  \
# 1                       Stay Cafeteria 慢走    Asian Restaurant
# 2                               Cafeteria  Mexican Restaurant
# 8           De La Salle College Cafeteria   College Cafeteria
# 20                               One Hour  Chinese Restaurant
# 21                                The Hub   College Cafeteria
# 22                             Marketeria          Restaurant
# 25                          Innis College      Student Center
# 28  George Brown College St. James Campus   Community College
#
#                address        lat        lng postalCode state
# 1      388 Spadina Ave  43.655454 -79.399163    M5T 2G5    ON
# 2       974 College St  43.653419 -79.427678    M6H 1A5    ON
# 8   131 Farnham Avenue  43.683003 -79.397815    M4V 1H7    ON
# 20    435 Spadina Ave.  43.657399 -79.399649    M5T 2T6    ON
# 21    350 Victoria St.  43.658585 -79.380622    M5B 2K3    ON
# 22         30 Bond St.  43.653585 -79.378843    M5B 1W8    ON
# 25        2 Sussex Ave  43.665556 -79.399298    M5S 1J5    ON
# 28      51 Dockside Dr  43.644163 -79.366375    M5A 0B6    ON

# %% [markdown]
# #### **Searching Shopping Store**

# %%
search_query = 'Shopping'
radius = 1000
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
sresults = requests.get(url).json()

venues = sresults['response']['venues']

Shopping_dataframe = json_normalize(venues)
Shopping_dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1fd941735', 'name': 'S...    False
# 1  [{'id': '4bf58dd8d48988d1fd941735', 'name': 'S...    False
# 2  [{'id': '4bf58dd8d48988d1fd941735', 'name': 'S...    False
# 3  [{'id': '4bf58dd8d48988d1f6941735', 'name': 'D...    False
# 4  [{'id': '4bf58dd8d48988d124941735', 'name': 'O...    False
#
#                          id    location.address location.cc location.city  \
# 0  4ad4c062f964a520fcf720e3     280 Spadina Ave          CA       Toronto
# 1  4ad77a12f964a520260b21e3        220 Yonge St          CA       Toronto
# 2  4b9e86dff964a520e6eb36e3  66 Wellington St W          CA       Toronto
# 3  5840cafe06f1a34af80cc609    176 Yonge Street          CA       Toronto
# 4  4b83d653f964a520d91231e3   461 King St. West          CA       Toronto
#
#   location.country location.crossStreet  location.distance  \
# 0           Canada       at Dundas St W                897
# 1           Canada  btwn Queen & Dundas                527
# 2           Canada    btw York & Bay St                908
# 3           Canada    Queen Street West                688
# 4           Canada                  NaN                974
#
#                            location.formattedAddress  \
# 0  [280 Spadina Ave (at Dundas St W), Toronto ON ...
# 1  [220 Yonge St (btwn Queen & Dundas), Toronto O...
# 2  [66 Wellington St W (btw York & Bay St), Toron...
# 3  [176 Yonge Street (Queen Street West), Toronto...
# 4    [461 King St. West, Toronto ON M5V 1K4, Canada]
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 43.65277367198862...     43.652774
# 1                                                NaN     43.653852
# 2  [{'label': 'display', 'lat': 43.64718424611984...     43.647184
# 3  [{'label': 'display', 'lat': 43.65181, 'lng': ...     43.651810
# 4  [{'label': 'display', 'lat': 43.64795765580337...     43.647958
#
#    location.lng          location.neighborhood location.postalCode  \
# 0    -79.398222                            NaN             M5T 3A5
# 1    -79.380655  Downtown Toronto, Toronto, ON             M5B 2H1
# 2    -79.380932                            NaN             M5K 1A1
# 3    -79.379192                            NaN             M5C 2L7
# 4    -79.396006                            NaN             M5V 1K4
#
#   location.state                                        name    referralId
# 0             ON                Dragon City Shopping Mall 龍城  v-1560908659
# 1             ON                     CF Toronto Eaton Centre  v-1560908659
# 2             ON                TD Centre Shopping Concourse  v-1560908659
# 3             ON  Saks Fifth Avenue Club - Personal Shopping  v-1560908659
# 4             ON             Yellow Pages - RedFlagDeals.com  v-1560908659

# %% [markdown]
# #### **Cleaning Dataframe**

# %%
Shopping_clean_columns = ['name', 'categories'] + [col for col in Shopping_dataframe.columns if col.startswith('location.')]+ ['id']
clean_Shopping_dataframe = Shopping_dataframe.loc[:,Shopping_clean_columns]

def get_category_type(row):
    try:
        categories_list5 = row['categories']
    except:
        categories_list5 = row['venue.categories']
        
    if len(categories_list5) == 0:
        return None
    else:
        return categories_list5[0]['name']

clean_Shopping_dataframe['categories'] = clean_Shopping_dataframe.apply(get_category_type, axis=1)

clean_Shopping_dataframe.columns = [column.split('.')[-1] for column in clean_Shopping_dataframe.columns]


clean_Shopping_dataframe2= clean_Shopping_dataframe.drop(['cc', 'city', 'country', 'crossStreet', 'distance', 'formattedAddress',\
                                        'labeledLatLngs', 'neighborhood', 'id'], axis=1)
clean_Shopping_dataframe2

df_Shopping = clean_Shopping_dataframe2[clean_Shopping_dataframe2.categories == 'Shopping Mall']
df_Shopping
# Out:
#                            name     categories             address        lat  \
# 0  Dragon City Shopping Mall 龍城  Shopping Mall     280 Spadina Ave  43.652774
# 1       CF Toronto Eaton Centre  Shopping Mall        220 Yonge St  43.653852
# 2  TD Centre Shopping Concourse  Shopping Mall  66 Wellington St W  43.647184
#
#          lng postalCode state
# 0 -79.398222    M5T 3A5    ON
# 1 -79.380655    M5B 2H1    ON
# 2 -79.380932    M5K 1A1    ON

# %% [markdown]
# #### **Generate map to visualize hotels,Park,Shopping stores and Cafeteria and how they cluster together**

# %%
hotel_neighbourhood_df = pd.concat([df_hotel, df_Cafeteria, df_Shopping], ignore_index=True)
hotel_neighbourhood_df


hotel_map = folium.Map(location=[latitude, longitude], zoom_start=14)

for lat, lng, name, categories, address in zip(hotel_neighbourhood_df['lat'], hotel_neighbourhood_df['lng'], 
                                           hotel_neighbourhood_df['name'], hotel_neighbourhood_df['categories'],\
                                               hotel_neighbourhood_df['address']):
    label = '{}, {}'.format(name, address)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='blue',
        fill_opacity=0.7,
        parse_html=False).add_to(hotel_map)  
    
hotel_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
park_neighbourhood_df = pd.concat([df_park,], ignore_index=True)
park_neighbourhood_df
park_map = folium.Map(location=[latitude, longitude], zoom_start=14)

for lat, lng, name, categories, address in zip(park_neighbourhood_df['lat'], park_neighbourhood_df['lng'], 
                                           park_neighbourhood_df['name'], park_neighbourhood_df['categories'],\
                                               park_neighbourhood_df['address']):
    label = '{}, {}'.format(name, address)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='blue',
        fill_opacity=0.7,
        parse_html=False).add_to(park_map)  
    
park_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
restaurant_neighbourhood_df = pd.concat([df_park, df_Restaurant, df_Cafeteria,], ignore_index=True)
restaurant_neighbourhood_df
restaurant_map = folium.Map(location=[latitude, longitude], zoom_start=14)

for lat, lng, name, categories, address in zip(restaurant_neighbourhood_df['lat'], restaurant_neighbourhood_df['lng'], 
                                           restaurant_neighbourhood_df['name'], restaurant_neighbourhood_df['categories'],\
                                               restaurant_neighbourhood_df['address']):
    label = '{}, {}'.format(name, address)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='blue',
        fill_opacity=0.7,
        parse_html=False).add_to(restaurant_map)  
    
restaurant_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
Shopping_neighbourhood_df = pd.concat([df_Shopping], ignore_index=True)
Shopping_neighbourhood_df
Shopping_map = folium.Map(location=[latitude, longitude], zoom_start=14)

for lat, lng, name, categories, address in zip(Shopping_neighbourhood_df['lat'], Shopping_neighbourhood_df['lng'], 
                                           Shopping_neighbourhood_df['name'], Shopping_neighbourhood_df['categories'],\
                                               Shopping_neighbourhood_df['address']):
    label = '{}, {}'.format(name, address)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='blue',
        fill_opacity=0.7,
        parse_html=False).add_to(Shopping_map)  
    
Shopping_map
